# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('fcc-forum-pageviews.csv', index_col='date', parse_dates=True)

# %%
df
# Out:
#              value
# date
# 2016-05-09    1201
# 2016-05-10    2329
# 2016-05-11    1716
# 2016-05-12   10539
# 2016-05-13    6933
# ...            ...
# 2019-11-29  171584
# 2019-11-30  141161
# 2019-12-01  142918
# 2019-12-02  220144
# 2019-12-03  158549
#
# [1304 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(df.index, df['value'], color='red', linewidth=1.5
            , label='Page Views')
ax.set_title('Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
ax.set_xlabel('Date')
ax.set_ylabel('Page Views')
# Out:
# Text(0, 0.5, 'Page Views')

# %%
df_bar = pd.read_csv('fcc-forum-pageviews.csv', index_col='date', parse_dates=True)

# %%
fig, ax = plt.subplots(figsize=(12, 8))
df_bar['year'] = df_bar.index.year
df_bar['month'] = df_bar.index.month_name()
ax.legend(title='Months')
sns.barplot(x='year', y='value', hue='month', data=df_bar)
# Out:
# C:\Users\tiise\AppData\Local\Temp\ipykernel_24436\618917439.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(title='Months')
# <Axes: xlabel='year', ylabel='value'>

# %%
df = pd.DataFrame({
    'Category': ['A', 'A', 'B', 'B', 'C', 'C'],
    'Gender': ['Male', 'Female'] * 3,
    'Values': [10, 12, 20, 22, 15, 17]
})

# Grouped bar plot
sns.barplot(x='Category', y='Values', hue='Gender', data=df)
plt.title("Grouped Bar Plot")
plt.show()

# %%
df_box = df.copy()
df_box.reset_index(inplace=True)
df_box['year'] = [d.year for d in df_box.date]
df_box['month'] = [d.strftime('%b') for d in df_box.date]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
sns.boxplot(x='year', y='value', data=df_box, ax=ax1
        , palette='viridis')
ax1.set_title('Year-wise Box Plot (Trend)')

sns.boxplot(x='month', y='value', data=df_box, ax=ax2
            , palette='viridis')
ax2.set_title('Month-wise Box Plot (Seasonality)')
# Out:
# C:\Users\tiise\AppData\Local\Temp\ipykernel_24436\3363195256.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='year', y='value', data=df_box, ax=ax1
# C:\Users\tiise\AppData\Local\Temp\ipykernel_24436\3363195256.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='month', y='value', data=df_box, ax=ax2
# Text(0.5, 1.0, 'Month-wise Box Plot (Seasonality)')
